# %% [markdown]
# ## Data

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data from CSV
data = pd.read_csv("AirQualityUCI.csv")
data.head()
# Out:
#          Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  10-03-2004  18:00:00     2.6       1360.0     150.0      11.9
# 1  10-03-2004  19:00:00     2.0       1292.0     112.0       9.4
# 2  10-03-2004  20:00:00     2.2       1402.0      88.0       9.0
# 3  10-03-2004  21:00:00     2.2       1376.0      80.0       9.2
# 4  10-03-2004  22:00:00     1.6       1272.0      51.0       6.5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0         1046.0    166.0        1056.0    113.0        1692.0       1268.0
# 1          955.0    103.0        1174.0     92.0        1559.0        972.0
# 2          939.0    131.0        1140.0    114.0        1555.0       1074.0
# 3          948.0    172.0        1092.0    122.0        1584.0       1203.0
# 4          836.0    131.0        1205.0    116.0        1490.0       1110.0
#
#       T    RH      AH  Unnamed: 15  Unnamed: 16
# 0  13.6  48.9  0.7578          NaN          NaN
# 1  13.3  47.7  0.7255          NaN          NaN
# 2  11.9  54.0  0.7502          NaN          NaN
# 3  11.0  60.0  0.7867          NaN          NaN
# 4  11.2  59.6  0.7888          NaN          NaN

# %%
print(data.shape)
data.describe()
# Out:
# (9471, 17)
#             CO(GT)  PT08.S1(CO)     NMHC(GT)     C6H6(GT)  PT08.S2(NMHC)  \
# count  9357.000000  9357.000000  9357.000000  9357.000000    9357.000000
# mean    -34.207524  1048.990061  -159.090093     1.865683     894.595276
# std      77.657170   329.832710   139.789093    41.380206     342.333252
# min    -200.000000  -200.000000  -200.000000  -200.000000    -200.000000
# 25%       0.600000   921.000000  -200.000000     4.000000     711.000000
# 50%       1.500000  1053.000000  -200.000000     7.900000     895.000000
# 75%       2.600000  1221.000000  -200.000000    13.600000    1105.000000
# max      11.900000  2040.000000  1189.000000    63.700000    2214.000000
#
#            NOx(GT)  PT08.S3(NOx)      NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# count  9357.000000   9357.000000  9357.000000   9357.000000  9357.000000
# mean    168.616971    794.990168    58.148873   1391.479641   975.072032
# std     257.433866    321.993552   126.940455    467.210125   456.938184
# min    -200.000000   -200.000000  -200.000000   -200.000000  -200.000000
# 25%      50.000000    637.000000    53.000000   1185.000000   700.000000
# 50%     141.000000    794.000000    96.000000   1446.000000   942.000000
# 75%     284.000000    960.000000   133.000000   1662.000000  1255.000000
# max    1479.000000   2683.000000   340.000000   2775.000000  2523.000000
#
#                  T           RH           AH  Unnamed: 15  Unnamed: 16
# count  9357.000000  9357.000000  9357.000000          0.0          0.0
# mean      9.778305    39.485380    -6.837604          NaN          NaN
# std      43.203623    51.216145    38.976670          NaN          NaN
# min    -200.000000  -200.000000  -200.000000          NaN          NaN
# 25%      10.900000    34.100000     0.692300          NaN          NaN
# 50%      17.200000    48.600000     0.976800          NaN          NaN
# 75%      24.100000    61.900000     1.296200          NaN          NaN
# max      44.600000    88.700000     2.231000          NaN          NaN

# %% [markdown]
# #  **Data Cleaning**

# %%
data = data.dropna(axis=1,how="all")
data
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0     10-03-2004  18:00:00     2.6       1360.0     150.0      11.9
# 1     10-03-2004  19:00:00     2.0       1292.0     112.0       9.4
# 2     10-03-2004  20:00:00     2.2       1402.0      88.0       9.0
# 3     10-03-2004  21:00:00     2.2       1376.0      80.0       9.2
# 4     10-03-2004  22:00:00     1.6       1272.0      51.0       6.5
# ...          ...       ...     ...          ...       ...       ...
# 9466         NaN       NaN     NaN          NaN       NaN       NaN
# 9467         NaN       NaN     NaN          NaN       NaN       NaN
# 9468         NaN       NaN     NaN          NaN       NaN       NaN
# 9469         NaN       NaN     NaN          NaN       NaN       NaN
# 9470         NaN       NaN     NaN          NaN       NaN       NaN
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# 1             955.0    103.0        1174.0     92.0        1559.0
# 2             939.0    131.0        1140.0    114.0        1555.0
# 3             948.0    172.0        1092.0    122.0        1584.0
# 4             836.0    131.0        1205.0    116.0        1490.0
# ...             ...      ...           ...      ...           ...
# 9466            NaN      NaN           NaN      NaN           NaN
# 9467            NaN      NaN           NaN      NaN           NaN
# 9468            NaN      NaN           NaN      NaN           NaN
# 9469            NaN      NaN           NaN      NaN           NaN
# 9470            NaN      NaN           NaN      NaN           NaN
#
#       PT08.S5(O3)     T    RH      AH
# 0          1268.0  13.6  48.9  0.7578
# 1           972.0  13.3  47.7  0.7255
# 2          1074.0  11.9  54.0  0.7502
# 3          1203.0  11.0  60.0  0.7867
# 4          1110.0  11.2  59.6  0.7888
# ...           ...   ...   ...     ...
# 9466          NaN   NaN   NaN     NaN
# 9467          NaN   NaN   NaN     NaN
# 9468          NaN   NaN   NaN     NaN
# 9469          NaN   NaN   NaN     NaN
# 9470          NaN   NaN   NaN     NaN
#
# [9471 rows x 15 columns]

# %%
plt.figure(figsize=(15,8))
sns.heatmap(data.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
data = data.drop('Date', axis=1)
data = data.drop('Time', axis=1)
# data = data.drop('C6H6(GT)', axis=1)
data = data.drop('PT08.S4(NO2)', axis=1)
data
# Out:
#       CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  \
# 0        2.6       1360.0     150.0      11.9         1046.0    166.0
# 1        2.0       1292.0     112.0       9.4          955.0    103.0
# 2        2.2       1402.0      88.0       9.0          939.0    131.0
# 3        2.2       1376.0      80.0       9.2          948.0    172.0
# 4        1.6       1272.0      51.0       6.5          836.0    131.0
# ...      ...          ...       ...       ...            ...      ...
# 9466     NaN          NaN       NaN       NaN            NaN      NaN
# 9467     NaN          NaN       NaN       NaN            NaN      NaN
# 9468     NaN          NaN       NaN       NaN            NaN      NaN
# 9469     NaN          NaN       NaN       NaN            NaN      NaN
# 9470     NaN          NaN       NaN       NaN            NaN      NaN
#
#       PT08.S3(NOx)  NO2(GT)  PT08.S5(O3)     T    RH      AH
# 0           1056.0    113.0       1268.0  13.6  48.9  0.7578
# 1           1174.0     92.0        972.0  13.3  47.7  0.7255
# 2           1140.0    114.0       1074.0  11.9  54.0  0.7502
# 3           1092.0    122.0       1203.0  11.0  60.0  0.7867
# 4           1205.0    116.0       1110.0  11.2  59.6  0.7888
# ...            ...      ...          ...   ...   ...     ...
# 9466           NaN      NaN          NaN   NaN   NaN     NaN
# 9467           NaN      NaN          NaN   NaN   NaN     NaN
# 9468           NaN      NaN          NaN   NaN   NaN     NaN
# 9469           NaN      NaN          NaN   NaN   NaN     NaN
# 9470           NaN      NaN          NaN   NaN   NaN     NaN
#
# [9471 rows x 12 columns]

# %%
data = data.dropna()
data
# Out:
#       CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  \
# 0        2.6       1360.0     150.0      11.9         1046.0    166.0
# 1        2.0       1292.0     112.0       9.4          955.0    103.0
# 2        2.2       1402.0      88.0       9.0          939.0    131.0
# 3        2.2       1376.0      80.0       9.2          948.0    172.0
# 4        1.6       1272.0      51.0       6.5          836.0    131.0
# ...      ...          ...       ...       ...            ...      ...
# 9352     3.1       1314.0    -200.0      13.5         1101.0    472.0
# 9353     2.4       1163.0    -200.0      11.4         1027.0    353.0
# 9354     2.4       1142.0    -200.0      12.4         1063.0    293.0
# 9355     2.1       1003.0    -200.0       9.5          961.0    235.0
# 9356     2.2       1071.0    -200.0      11.9         1047.0    265.0
#
#       PT08.S3(NOx)  NO2(GT)  PT08.S5(O3)     T    RH      AH
# 0           1056.0    113.0       1268.0  13.6  48.9  0.7578
# 1           1174.0     92.0        972.0  13.3  47.7  0.7255
# 2           1140.0    114.0       1074.0  11.9  54.0  0.7502
# 3           1092.0    122.0       1203.0  11.0  60.0  0.7867
# 4           1205.0    116.0       1110.0  11.2  59.6  0.7888
# ...            ...      ...          ...   ...   ...     ...
# 9352         539.0    190.0       1729.0  21.9  29.3  0.7568
# 9353         604.0    179.0       1269.0  24.3  23.7  0.7119
# 9354         603.0    175.0       1092.0  26.9  18.3  0.6406
# 9355         702.0    156.0        770.0  28.3  13.5  0.5139
# 9356         654.0    168.0        816.0  28.5  13.1  0.5028
#
# [9357 rows x 12 columns]

# %%
from sklearn.model_selection import train_test_split 

X = data.drop(['C6H6(GT)'], axis=1).values
Y = data['C6H6(GT)'].values

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# %% [markdown]
# # Using Different Regression Models To Make Predictions

# %%
from sklearn import metrics 
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor 

model = RandomForestRegressor(random_state=0)
model.fit(X,Y)

# EVALUATING THE MODEL
yrand = model.predict(X_test)

# %%
# EVALUATING MODEL PREDICTIONS
rand_score_train = model.score(X_train,Y_train)
rand_score_test = model.score(X_test,Y_test)
rand_mean = mean_absolute_error(Y_test, yrand)
rand_mean_square_error = mean_squared_error(Y_test, yrand)
rand_rmse = np.sqrt(mean_squared_error(Y_test, yrand))
rand_mape = metrics.mean_absolute_percentage_error(Y_test, yrand)

print('Accuracy of trained data:', rand_score_train)
print('Accuracy of test data:', rand_score_test)
print('mean absolute error:', rand_mean)
print('root mean squared error:', rand_rmse)
print('mean absolute percentage error:', rand_mape)
# Out:
# Accuracy of trained data: 0.9999974513261757
# Accuracy of test data: 0.9999983907268595
# mean absolute error: 0.004964743589749058
# root mean squared error: 0.05240930301707
# mean absolute percentage error: 0.0005570065743509331

# %%
from statsmodels.regression.linear_model import OLS
from statsmodels.tools import add_constant
randR = OLS(Y_test, add_constant(yrand)).fit()
print('AIC', randR.aic)
# Out:
# AIC -5725.0010001319515

# %% [markdown]
# ### Ridge Regression

# %%
from sklearn.linear_model import Ridge

# RIGDE REGRESSION
ridge = Ridge()
ridge.fit(X_train, Y_train)

# EVALUATING THE MODEL
yridge = ridge.predict(X_test)

# %%
# EVALUATING MODEL PREDICTIONS
ridge_score_train = ridge.score(X_train,Y_train)
ridge_score_test = ridge.score(X_test,Y_test)
ridge_mean = metrics.mean_absolute_error(Y_test, yridge)
ridge_mean_square_error = metrics.mean_squared_error(Y_test, yridge)
ridge_rmse = np.sqrt(metrics.mean_squared_error(Y_test, yridge))
ridge_mape = metrics.mean_absolute_percentage_error(Y_test, yridge)

print('Accuracy of trained data:', ridge_score_train)
print('Accuracy of test data:', ridge_score_test)
print('mean absolute error:', ridge_mean)
print('root mean squared error:', ridge_rmse)
print('mean absolute percentage error:', ridge_mape)
# Out:
# Accuracy of trained data: 0.9992272123204314
# Accuracy of test data: 0.999263226679356
# mean absolute error: 0.8043281806410235
# root mean squared error: 1.1213997329427803
# mean absolute percentage error: 0.2063186948284143

# %%
from statsmodels.regression.linear_model import OLS
from statsmodels.tools import add_constant
ridger = OLS(Y_test, add_constant(yridge)).fit()
print('AIC', ridger.aic)
# Out:
# AIC 5743.8841862475

# %% [markdown]
# ### Bagging Regression

# %%
from sklearn.ensemble import BaggingRegressor

Bag = BaggingRegressor()
Bag.fit(X_train,Y_train)

# EVALUATING THE MODEL
yBag = Bag.predict(X_test)

# %%
# EVALUATING MODEL PREDICTIONS
Bag_score_train = Bag.score(X_train,Y_train)
Bag_score_test = Bag.score(X_test,Y_test)
Bag_mean = metrics.mean_absolute_error(Y_test, yBag)
Bag_mean_square_error = metrics.mean_squared_error(Y_test, yBag)
Bag_rmse = np.sqrt(metrics.mean_squared_error(Y_test, yBag))
Bag_mape = metrics.mean_absolute_percentage_error(Y_test, yBag)

print('Accuracy of trained data:', Bag_score_train)
print('Accuracy of test data:', Bag_score_test)
print('mean absolute error:', Bag_mean)
print('root mean squared error:', Bag_rmse)
print('mean absolute percentage error:', Bag_mape)
# Out:
# Accuracy of trained data: 0.9999970385359841
# Accuracy of test data: 0.9999939278504634
# mean absolute error: 0.014877136752137338
# root mean squared error: 0.10180397411348517
# mean absolute percentage error: 0.0016065782275427843

# %%
from statsmodels.regression.linear_model import OLS
from statsmodels.tools import add_constant
BagR = OLS(Y_test, add_constant(yBag)).fit()
print('AIC', BagR.aic)
# Out:
# AIC -3237.521959927617

# %% [markdown]
# ### Extra Tree Regression

# %%
from sklearn.ensemble import ExtraTreesRegressor 

extra = ExtraTreesRegressor()
extra.fit(X_train,Y_train)

# EVALUATING THE MODEL
yextra = extra.predict(X_test)

# %%
# EVALUATING MODEL PREDICTIONS
extra_score_train = extra.score(X_train,Y_train)
extra_score_test = extra.score(X_test,Y_test)
extra_mean = metrics.mean_absolute_error(Y_test, yextra)
extra_mean_square_error = metrics.mean_squared_error(Y_test, yextra)
extra_rmse = np.sqrt(metrics.mean_squared_error(Y_test, yextra))
extra_mape = metrics.mean_absolute_percentage_error(Y_test, yextra)

print('Accuracy of trained data:', extra_score_train)
print('Accuracy of test data:', extra_score_test)
print('mean absolute error:', extra_mean)
print('root mean squared error:', extra_rmse)
print('mean absolute percentage error:', extra_mape)
# Out:
# Accuracy of trained data: 1.0
# Accuracy of test data: 0.9999976060038349
# mean absolute error: 0.019904380341880502
# root mean squared error: 0.06392271726116859
# mean absolute percentage error: 0.0025808854622509907

# %%
from statsmodels.regression.linear_model import OLS
from statsmodels.tools import add_constant
extraR = OLS(Y_test, add_constant(yextra)).fit()
print('AIC', extraR.aic)
# Out:
# AIC -4981.508579006902

# %% [markdown]
# ### XGB Regression

# %%
from xgboost.sklearn import XGBRegressor

xgb = XGBRegressor()
xgb.fit(X_train,Y_train)

# EVALUATING THE MODEL
yxgb = xgb.predict(X_test)

# %%
# EVALUATING MODEL PREDICTIONS
xgb_score_train = xgb.score(X_train,Y_train)
xgb_score_test = xgb.score(X_test,Y_test)
xgb_mean = metrics.mean_absolute_error(Y_test, yxgb)
xgb_mean_square_error = metrics.mean_squared_error(Y_test, yxgb)
xgb_rmse = np.sqrt(metrics.mean_squared_error(Y_test, yxgb))
xgb_mape = metrics.mean_absolute_percentage_error(Y_test, yxgb)

print('Accuracy of trained data:', xgb_score_train)
print('Accuracy of test data:', xgb_score_test)
print('mean absolute error:', xgb_mean)
print('root mean squared error:', xgb_rmse)
print('mean absolute percentage error:', xgb_mape)
# Out:
# Accuracy of trained data: 0.9999997152946362
# Accuracy of test data: 0.9999979688207746
# mean absolute error: 0.027537903377515657
# root mean squared error: 0.058879976192394164
# mean absolute percentage error: 0.003784054128111289

# %%
from statsmodels.regression.linear_model import OLS
from statsmodels.tools import add_constant
xgbR = OLS(Y_test, add_constant(yxgb)).fit()
print('AIC', xgbR.aic)
# Out:
# AIC -5289.161847908224

# %% [markdown]
# ### Linear Regression

# %%
from sklearn.linear_model import LinearRegression

lin = LinearRegression()
lin.fit(X_train,Y_train)

# EVALUATING THE MODEL
ylin = lin.predict(X_test)

# %%
lin_score_train = lin.score(X_train,Y_train)
lin_score_test = lin.score(X_test,Y_test)
lin_mean = metrics.mean_absolute_error(Y_test, ylin)
lin_mean_square_error = metrics.mean_squared_error(Y_test, ylin)
lin_rmse = np.sqrt(metrics.mean_squared_error(Y_test, ylin))
lin_mape = metrics.mean_absolute_percentage_error(Y_test, ylin)

print('Accuracy of trained data:', lin_score_train)
print('Accuracy of test data:', lin_score_test)
print('mean absolute error:', lin_mean)
print('root mean squared error:', lin_rmse)
print('mean absolute percentage error:', lin_mape)
# Out:
# Accuracy of trained data: 0.9992272123212226
# Accuracy of test data: 0.9992632272043386
# mean absolute error: 0.8043295193705564
# root mean squared error: 1.1213993334200278
# mean absolute percentage error: 0.206318422098818

# %%
from statsmodels.regression.linear_model import OLS
from statsmodels.tools import add_constant
linR = OLS(Y_test, add_constant(ylin)).fit()
print('AIC', linR.aic)
# Out:
# AIC 5743.882625617402

# %% [markdown]
# ## Making A Dataframe For The Models

# %%
summary = pd.DataFrame()
summary['Models'] = ['RandomForest','Ridge Regression', 'Extra Tree Regression', 'XGBoost Regression', 'Bagging Regression', 'Linear Regression']
summary['Train_Score'] = rand_score_train, ridge_score_train, extra_score_train, xgb_score_train, Bag_score_train, lin_score_train
summary['Test_Score'] = rand_score_test, ridge_score_test, extra_score_test, xgb_score_test, Bag_score_test, lin_score_test
summary['AIC'] = randR.aic, ridger.aic, extraR.aic, xgbR.aic, BagR.aic, linR.aic
summary['Mean_Absolute_Error'] = rand_mean, ridge_mean, extra_mean, xgb_mean, Bag_mean, lin_mean
summary['Root_Mean_Squared_Error'] = rand_rmse, ridge_rmse, extra_rmse, xgb_rmse, Bag_rmse, lin_rmse
summary['Mean_Absolute_Percentage_Error'] = rand_mape, ridge_mape, extra_mape, xgb_mape, Bag_mape, lin_mape
summary
# Out:
#                   Models  Train_Score  Test_Score          AIC  \
# 0           RandomForest     0.999997    0.999998 -5725.001000
# 1       Ridge Regression     0.999227    0.999263  5743.884186
# 2  Extra Tree Regression     1.000000    0.999998 -4981.508579
# 3     XGBoost Regression     1.000000    0.999998 -5289.161848
# 4     Bagging Regression     0.999997    0.999994 -3237.521960
# 5      Linear Regression     0.999227    0.999263  5743.882626
#
#    Mean_Absolute_Error  Root_Mean_Squared_Error  \
# 0             0.004965                 0.052409
# 1             0.804328                 1.121400
# 2             0.019904                 0.063923
# 3             0.027538                 0.058880
# 4             0.014877                 0.101804
# 5             0.804330                 1.121399
#
#    Mean_Absolute_Percentage_Error
# 0                        0.000557
# 1                        0.206319
# 2                        0.002581
# 3                        0.003784
# 4                        0.001607
# 5                        0.206318

# %% [markdown]
# # Testing The Models

# %%
# EVALUATING THE EXTRA TREE MODEL - BEST MODEL
yextra = extra.predict(X_test)
yextra
# Out:
# array([   5.193,    1.583,    2.403, ..., -200.   ,    3.6  ,    7.994])

# %%
test = pd.DataFrame()
test['Actual'] = Y_test
test['ExtraTree_Prediction'] = yextra
test
# Out:
#       Actual  ExtraTree_Prediction
# 0        5.2                 5.193
# 1        1.6                 1.583
# 2        2.4                 2.403
# 3        2.3                 2.319
# 4        3.0                 2.988
# ...      ...                   ...
# 1867     8.2                 8.127
# 1868    13.7                13.666
# 1869  -200.0              -200.000
# 1870     3.6                 3.600
# 1871     8.0                 7.994
#
# [1872 rows x 2 columns]

# %% [markdown]
# # Visualise Predictions

# %%
plt.xlabel("Predicted C6H6 (µg/m^3)")
plt.ylabel("Actual C6H6 (µg/m^3)")

# Plotting actual values in blue and predicted values in red
plt.scatter(yextra, Y_test, color='green', label='Predicted')
plt.scatter(Y_test, Y_test, color='blue', label='Actual')

plt.legend()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(11.7, 8.27))
# Plot curve for Actual values
sns.lineplot(data=test['Actual'], ax=ax, color='r', label='Actual')
# Plot curve for Predicted values
sns.lineplot(data=test['ExtraTree_Prediction'], ax=ax, color='b', label='Predicted Values')

ax.legend()
plt.show()

# %%
fig,ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)

ax1 = sns.distplot(test['Actual'], hist=False, color='r', label='Actual')
sns.distplot(test['ExtraTree_Prediction'], hist=False, color='b', label='Predicted Values', ax=ax1)
plt.ylabel('Actual')
plt.legend()
# Out:
# C:\Users\Hakeem\AppData\Local\Temp\ipykernel_14812\1085324658.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax1 = sns.distplot(test['Actual'], hist=False, color='r', label='Actual')
# C:\Users\Hakeem\AppData\Local\Temp\ipykernel_14812\1085324658.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(test['ExtraTree_Prediction'], hist=False, color='b', label='Predicted Values', ax=ax1)

# %%
fig = sns.lmplot(x='ExtraTree_Prediction', y='Actual', data=test)
plt.gca().set()
# Out:
# []

# %% [markdown]
# # Saving The Model

# %%
import pickle 

# saving the model
with open ("AQModel.pkl", 'wb') as file:
    pickle.dump(extra, file)
